# %%
# import openai
# import os

    # Set your API key (replace with your actual key or environment variable)
    #openai.api_key = os.getenv("OPENAI_API_KEY") # Recommended
    # Or: openai.api_key = "sk-YOUR_SECRET_API_KEY" # Not recommended for production

# %%
import google.generativeai as genai
import os

os.environ["GEMINI_API_KEY"] = "AIzaSyAK74sv5g6i4WTtYzovaikSrv4QDdZ457o"

# The SDK automatically uses the API key from the environment variable
# GEMINI_API_KEY. If you haven't set it, you can configure it like this:
genai.configure(api_key="AIzaSyAK74sv5g6i4WTtYzovaikSrv4QDdZ457o")

try:
    # Check if the API key is available from the environment variable
    if not os.getenv("GEMINI_API_KEY"):
        raise ValueError("GEMINI_API_KEY environment variable not set.")
    
    # Create an instance of the Gemini model (gemini-2.5-flash is fast and suitable for chat)
    model = genai.GenerativeModel('gemini-2.5-flash')

    # Start a chat session to maintain conversation history
    chat = model.start_chat(history=[])

    print("Welcome to Scouting AI Chatbot! Type 'exit' to quit.")

    # Main chat loop
    while True:
        user_input = input("You: ")
        if user_input.lower() == 'exit':
            break

        # Send the user's message to the model and get a response
        response = chat.send_message(user_input)
        
        # Print the model's response
        print(f"Bot: {response.text.strip()}")

except ValueError as e:
    print(f"Error: {e}")
    print("Please set the GEMINI_API_KEY environment variable and try again.")
except Exception as e:
    print(f"An unexpected error occurred: {e}")
# Out:
# Welcome to Scouting AI Chatbot! Type 'exit' to quit.
# You:  what is scout law?
# Bot: The **Scout Law** is a fundamental code of conduct and a set of guiding principles for members of the Scouting movement worldwide. While the exact wording and number of points can vary slightly between different national organizations (like Boy Scouts of America, Scouts UK, etc.) and between Boy Scouts/Girl Scouts, the core values and meaning remain consistent.
#
# It's designed to help Scouts develop good character, become responsible citizens, and live a life of integrity and service.
#
# Here is the most common version, as used by the **Boy Scouts of America (BSA)**, which consists of 12 points:
#
# **A Scout is:**
#
# 1.  **Trustworthy:** A Scout tells the truth and keeps promises. Honesty is part of a Scout's code of conduct. People can depend on a Scout.
# 2.  **Loyal:** A Scout is true to their family, friends, leaders, school, and country.
# ...
